# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Chelsea\Downloads\projects\tfenv\Scripts\python.exe -m pip install --upgrade pip

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Chelsea\Downloads\projects\tfenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Chelsea\Downloads\projects\tfenv\Scripts\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 3.0.5

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

print("Dataset loaded successfully!")
print("Number of rows:", data.data.shape[0])
print("Number of features:", data.data.shape[1])
# Out:
# Dataset loaded successfully!
# Number of rows: 569
# Number of features: 30

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target

df.to_csv("breast_cancer_dataset.csv", index=False)

print("Dataset saved successfully!")
print("Shape:", df.shape)
# Out:
# Dataset saved successfully!
# Shape: (569, 31)
